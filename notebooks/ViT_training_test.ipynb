# %% [markdown]
# # Final Implementation test
# This notebook was hosted in Colab and used to train the full network, plots can be found under `reports/figures`.

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJECT_PATH = '/content/drive/MyDrive/Colab\ Notebooks/ViT'

DRIVE_PYTHON_PATH = PROJECT_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PYTHON_PATH

SYM_PATH = '/content/ViT'
if not os.path.exists(SYM_PATH):
  # !ln -s $PROJECT_PATH $SYM_PATH

# %cd $PROJECT_PATH
# Out:
# /content/drive/MyDrive/Colab Notebooks/ViT

# %%
# !git clone https://github.com/fadibenz/ViT
# Out:
# Cloning into 'ViT'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 0), reused 21 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 22.93 KiB | 434.00 KiB/s, done.

# %%
# %cd ViT
# Out:
# /content/drive/MyDrive/Colab Notebooks/ViT/ViT

# %%
# !pip install -r requirements.txt
# Out:
# Obtaining file:///content/drive/MyDrive/Colab%20Notebooks/ViT/ViT (from -r requirements.txt (line 14))
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 50.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...

# %%
# !python ViT/main.py
# Out:
#   0% 0/10 [00:00<?, ?it/s]
#   0% 0/79 [00:00<?, ?it/s]
#   0% 0/79 [00:00<?, ?it/s, loss=2.39, train_acc=0.117]
#   1% 1/79 [00:00<00:37,  2.09it/s, loss=2.39, train_acc=0.117]
#   1% 1/79 [00:00<00:37,  2.09it/s, loss=2.97, train_acc=0.18]
#   1% 1/79 [00:00<00:37,  2.09it/s, loss=2.61, train_acc=0.148]
#   4% 3/79 [00:00<00:14,  5.29it/s, loss=2.61, train_acc=0.148]
#   4% 3/79 [00:00<00:14,  5.29it/s, loss=2.45, train_acc=0.172]
#   4% 3/79 [00:00<00:14,  5.29it/s, loss=2.27, train_acc=0.133]
#   6% 5/79 [00:00<00:09,  7.64it/s, loss=2.27, train_acc=0.133]
#   6% 5/79 [00:00<00:09,  7.64it/s, loss=2.33, train_acc=0.195]
#   6% 5/79 [00:00<00:09,  7.64it/s, loss=2.31, train_acc=0.219]
#   9% 7/79 [00:00<00:07,  9.53it/s, loss=2.31, train_acc=0.219]
#   9% 7/79 [00:01<00:07,  9.53it/s, loss=2.23, train_acc=0.188]
#   9% 7/79 [00:01<00:07,  9.53it/s, loss=2.3, train_acc=0.195]
#  11% 9/79 [00:01<00:06, 10.68it/s, loss=2.3, train_acc=0.195]
# ...

# %% [markdown]
# ### Conclusion
# We can see that our implementation is correct, although it scores poorly. This is because attention mechanisms are very data hungry and we have not trained on remotely enough data.
